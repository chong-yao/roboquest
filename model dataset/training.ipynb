# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.export(format="openvino")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 23.9MB/s]
# Ultralytics 8.3.131  Python-3.12.11 torch-2.7.0+cpu CPU (13th Gen Intel Core(TM) i5-13500HX)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirement ['openvino>=2024.0.0'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 39.5/39.5 MB 30.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 2/2 [openvino]telemetry]
# ...
#
# requirements: AutoUpdate success  18.5s, installed 1 package: ['openvino>=2024.0.0']
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
#
# OpenVINO: starting export with openvino 2025.2.0-19140-c01cd93e24d-releases/2025/2...
# OpenVINO: export success  22.2s, saved as 'yolov8n_openvino_model\' (12.3 MB)
#
# Export complete (22.7s)
# ...
